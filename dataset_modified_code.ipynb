# %%
import os

import cv2
import pandas as pd


from tqdm import tqdm

# for reading and displaying images
from skimage.io import imread
from skimage.transform import resize
import matplotlib.pyplot as plt
# %matplotlib inline

# for creating validation set
from sklearn.model_selection import train_test_split

# for evaluating the model
from sklearn.metrics import accuracy_score

# PyTorch libraries and modules
import torch
from torch.autograd import Variable
from torch.nn import Linear, ReLU, CrossEntropyLoss, Sequential, Conv2d, MaxPool2d, Module, Softmax, BatchNorm2d, Dropout
from torch.optim import Adam, SGD

# torchvision for pre-trained models
from torchvision import models
import argparse
from collections import Counter
import time

import numpy as np

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
    df = pd.read_csv("/content/gdrive/MyDrive/mini-MIAS/data_description.csv", header=None, index_col=0)
    df[1].str.strip()  # Strip leading and trailing spaces in label column.

    # print(df[1])

    for img_pgm in os.listdir("/content/gdrive/MyDrive/mini-MIAS/images_original"):
        if img_pgm.endswith(".pgm"):
            img = cv2.imread("/content/gdrive/MyDrive/mini-MIAS/images_original/{}".format(img_pgm))
            img_name = img_pgm.split(".")[0]
            label = df.loc[img_name].loc[1]
            if label == 'G ':
                new_path = "/content/gdrive/MyDrive/mini-MIAS/images_processed/fatty_glandular/{}.png".format(img_name)
                print("Image {} moved to Fatty-Glandular({} case).".format(img_pgm, label))
            elif label == 'D ':
                new_path = "/content/gdrive/MyDrive/mini-MIAS/images_processed/dense_glandular/{}.png".format(img_name)
                print("Image {} moved to Dense-Glandular({} case).".format(img_pgm, label))

            elif label == 'F ':
                new_path = "/content/gdrive/MyDrive/mini-MIAS/images_processed/fatty/{}.png".format(img_name)
                print("Image {} moved to Fatty({} case).".format(img_pgm, label))

            cv2.imwrite(new_path, img)


    print("Finished converting and sorting dataset.")
# Out:
# Image mdb008.pgm moved to Fatty-Glandular(G  case).
# Image mdb009.pgm moved to Fatty(F  case).
# Image mdb006.pgm moved to Fatty(F  case).
# Image mdb001.pgm moved to Fatty-Glandular(G  case).
# Image mdb010.pgm moved to Fatty(F  case).
# Image mdb004.pgm moved to Dense-Glandular(D  case).
# Image mdb012.pgm moved to Fatty(F  case).
# Image mdb011.pgm moved to Fatty(F  case).
# Image mdb015.pgm moved to Fatty-Glandular(G  case).
# Image mdb005.pgm moved to Fatty(F  case).
# Image mdb017.pgm moved to Fatty-Glandular(G  case).
# Image mdb013.pgm moved to Fatty-Glandular(G  case).
# Image mdb002.pgm moved to Fatty-Glandular(G  case).
# Image mdb007.pgm moved to Fatty-Glandular(G  case).
# Image mdb018.pgm moved to Fatty-Glandular(G  case).
# Image mdb014.pgm moved to Fatty-Glandular(G  case).
# Image mdb003.pgm moved to Dense-Glandular(D  case).
# Image mdb019.pgm moved to Fatty-Glandular(G  case).
# Image mdb016.pgm moved to Fatty-Glandular(G  case).
# Image mdb025.pgm moved to Fatty(F  case).
# Image mdb023.pgm moved to Fatty-Glandular(G  case).
# Image mdb039.pgm moved to Dense-Glandular(D  case).
# Image mdb035.pgm moved to Dense-Glandular(D  case).
# Image mdb040.pgm moved to Dense-Glandular(D  case).
# Image mdb038.pgm moved to Dense-Glandular(D  case).
# Image mdb031.pgm moved to Fatty-Glandular(G  case).
# Image mdb024.pgm moved to Fatty-Glandular(G  case).
# Image mdb042.pgm moved to Fatty-Glandular(G  case).
# Image mdb037.pgm moved to Dense-Glandular(D  case).
# Image mdb026.pgm moved to Fatty(F  case).
# Image mdb022.pgm moved to Fatty-Glandular(G  case).
# Image mdb027.pgm moved to Fatty(F  case).
# Image mdb021.pgm moved to Fatty-Glandular(G  case).
# Image mdb029.pgm moved to Fatty-Glandular(G  case).
# Image mdb032.pgm moved to Fatty-Glandular(G  case).
# Image mdb020.pgm moved to Fatty-Glandular(G  case).
# Image mdb028.pgm moved to Fatty(F  case).
# Image mdb034.pgm moved to Dense-Glandular(D  case).
# Image mdb033.pgm moved to Dense-Glandular(D  case).
# Image mdb036.pgm moved to Dense-Glandular(D  case).
# Image mdb030.pgm moved to Fatty-Glandular(G  case).
# Image mdb041.pgm moved to Fatty-Glandular(G  case).
# Image mdb054.pgm moved to Dense-Glandular(D  case).
# Image mdb060.pgm moved to Fatty(F  case).
# Image mdb063.pgm moved to Dense-Glandular(D  case).
# Image mdb048.pgm moved to Fatty-Glandular(G  case).
# Image mdb045.pgm moved to Fatty-Glandular(G  case).
# Image mdb044.pgm moved to Fatty-Glandular(G  case).
# Image mdb065.pgm moved to Dense-Glandular(D  case).
# Image mdb058.pgm moved to Dense-Glandular(D  case).
# Image mdb049.pgm moved to Fatty-Glandular(G  case).
# Image mdb064.pgm moved to Dense-Glandular(D  case).
# Image mdb043.pgm moved to Fatty-Glandular(G  case).
# Image mdb051.pgm moved to Fatty-Glandular(G  case).
# Image mdb052.pgm moved to Fatty-Glandular(G  case).
# Image mdb056.pgm moved to Fatty-Glandular(G  case).
# Image mdb053.pgm moved to Dense-Glandular(D  case).
# Image mdb066.pgm moved to Dense-Glandular(D  case).
# Image mdb061.pgm moved to Dense-Glandular(D  case).
# Image mdb057.pgm moved to Dense-Glandular(D  case).
# Image mdb050.pgm moved to Fatty-Glandular(G  case).
# Image mdb062.pgm moved to Dense-Glandular(D  case).
# Image mdb055.pgm moved to Fatty-Glandular(G  case).
# Image mdb046.pgm moved to Fatty-Glandular(G  case).
# Image mdb047.pgm moved to Fatty-Glandular(G  case).
# Image mdb059.pgm moved to Fatty(F  case).
# Image mdb067.pgm moved to Dense-Glandular(D  case).
# Image mdb077.pgm moved to Fatty(F  case).
# Image mdb085.pgm moved to Fatty-Glandular(G  case).
# Image mdb092.pgm moved to Fatty(F  case).
# Image mdb069.pgm moved to Fatty(F  case).
# Image mdb073.pgm moved to Fatty-Glandular(G  case).
# Image mdb083.pgm moved to Fatty-Glandular(G  case).
# Image mdb076.pgm moved to Fatty(F  case).
# Image mdb071.pgm moved to Fatty-Glandular(G  case).
# Image mdb078.pgm moved to Fatty(F  case).
# Image mdb075.pgm moved to Fatty(F  case).
# Image mdb082.pgm moved to Fatty-Glandular(G  case).
# Image mdb090.pgm moved to Fatty-Glandular(G  case).
# Image mdb080.pgm moved to Fatty(F  case).
# Image mdb081.pgm moved to Fatty-Glandular(G  case).
# Image mdb091.pgm moved to Fatty(F  case).
# Image mdb086.pgm moved to Fatty-Glandular(G  case).
# Image mdb068.pgm moved to Dense-Glandular(D  case).
# Image mdb070.pgm moved to Fatty(F  case).
# Image mdb084.pgm moved to Fatty-Glandular(G  case).
# Image mdb089.pgm moved to Fatty-Glandular(G  case).
# Image mdb072.pgm moved to Fatty-Glandular(G  case).
# Image mdb088.pgm moved to Fatty(F  case).
# Image mdb079.pgm moved to Fatty(F  case).
# Image mdb074.pgm moved to Fatty-Glandular(G  case).
# Image mdb087.pgm moved to Fatty(F  case).
# Image mdb095.pgm moved to Fatty(F  case).
# Image mdb093.pgm moved to Fatty-Glandular(G  case).
# Image mdb100.pgm moved to Dense-Glandular(D  case).
# Image mdb103.pgm moved to Dense-Glandular(D  case).
# Image mdb106.pgm moved to Dense-Glandular(D  case).
# Image mdb101.pgm moved to Dense-Glandular(D  case).
# Image mdb097.pgm moved to Fatty(F  case).
# Image mdb099.pgm moved to Dense-Glandular(D  case).
# Image mdb108.pgm moved to Dense-Glandular(D  case).
# Image mdb096.pgm moved to Fatty(F  case).
# Image mdb111.pgm moved to Dense-Glandular(D  case).
# Image mdb105.pgm moved to Dense-Glandular(D  case).
# Image mdb115.pgm moved to Fatty-Glandular(G  case).
# Image mdb109.pgm moved to Dense-Glandular(D  case).
# Image mdb107.pgm moved to Dense-Glandular(D  case).
# Image mdb112.pgm moved to Dense-Glandular(D  case).
# Image mdb114.pgm moved to Fatty-Glandular(G  case).
# Image mdb110.pgm moved to Dense-Glandular(D  case).
# Image mdb102.pgm moved to Dense-Glandular(D  case).
# Image mdb094.pgm moved to Fatty-Glandular(G  case).
# Image mdb117.pgm moved to Fatty-Glandular(G  case).
# Image mdb113.pgm moved to Fatty-Glandular(G  case).
# Image mdb098.pgm moved to Fatty(F  case).
# Image mdb116.pgm moved to Fatty-Glandular(G  case).
# Image mdb104.pgm moved to Dense-Glandular(D  case).
# Image mdb121.pgm moved to Fatty-Glandular(G  case).
# Image mdb127.pgm moved to Fatty-Glandular(G  case).
# Image mdb138.pgm moved to Dense-Glandular(D  case).
# Image mdb123.pgm moved to Fatty-Glandular(G  case).
# Image mdb131.pgm moved to Fatty(F  case).
# Image mdb120.pgm moved to Fatty-Glandular(G  case).
# Image mdb118.pgm moved to Fatty-Glandular(G  case).
# Image mdb132.pgm moved to Fatty(F  case).
# Image mdb122.pgm moved to Fatty-Glandular(G  case).
# Image mdb130.pgm moved to Dense-Glandular(D  case).
# Image mdb129.pgm moved to Dense-Glandular(D  case).
# Image mdb128.pgm moved to Fatty-Glandular(G  case).
# Image mdb119.pgm moved to Fatty-Glandular(G  case).
# Image mdb126.pgm moved to Dense-Glandular(D  case).
# Image mdb133.pgm moved to Fatty(F  case).
# Image mdb137.pgm moved to Dense-Glandular(D  case).
# Image mdb134.pgm moved to Fatty(F  case).
# Image mdb136.pgm moved to Fatty(F  case).
# Image mdb124.pgm moved to Fatty-Glandular(G  case).
# Image mdb135.pgm moved to Fatty(F  case).
# Image mdb125.pgm moved to Dense-Glandular(D  case).
# Image mdb144.pgm moved to Fatty(F  case).
# Image mdb155.pgm moved to Fatty(F  case).
# Image mdb152.pgm moved to Fatty(F  case).
# Image mdb140.pgm moved to Fatty(F  case).
# Image mdb145.pgm moved to Dense-Glandular(D  case).
# Image mdb154.pgm moved to Fatty(F  case).
# Image mdb151.pgm moved to Fatty(F  case).
# Image mdb147.pgm moved to Fatty(F  case).
# Image mdb142.pgm moved to Fatty(F  case).
# Image mdb141.pgm moved to Fatty(F  case).
# Image mdb150.pgm moved to Fatty(F  case).
# Image mdb153.pgm moved to Fatty(F  case).
# Image mdb156.pgm moved to Fatty(F  case).
# Image mdb149.pgm moved to Fatty(F  case).
# Image mdb143.pgm moved to Fatty(F  case).
# Image mdb139.pgm moved to Fatty(F  case).
# Image mdb146.pgm moved to Dense-Glandular(D  case).
# Image mdb148.pgm moved to Fatty(F  case).
# Image mdb166.pgm moved to Dense-Glandular(D  case).
# Image mdb179.pgm moved to Dense-Glandular(D  case).
# Image mdb163.pgm moved to Dense-Glandular(D  case).
# Image mdb172.pgm moved to Dense-Glandular(D  case).
# Image mdb167.pgm moved to Fatty(F  case).
# Image mdb174.pgm moved to Fatty(F  case).
# Image mdb161.pgm moved to Dense-Glandular(D  case).
# Image mdb175.pgm moved to Fatty-Glandular(G  case).
# Image mdb170.pgm moved to Dense-Glandular(D  case).
# Image mdb169.pgm moved to Dense-Glandular(D  case).
# Image mdb177.pgm moved to Fatty-Glandular(G  case).
# Image mdb168.pgm moved to Fatty(F  case).
# Image mdb176.pgm moved to Fatty-Glandular(G  case).
# Image mdb183.pgm moved to Fatty(F  case).
# Image mdb164.pgm moved to Dense-Glandular(D  case).
# Image mdb180.pgm moved to Dense-Glandular(D  case).
# Image mdb173.pgm moved to Fatty(F  case).
# Image mdb160.pgm moved to Fatty(F  case).
# Image mdb157.pgm moved to Fatty(F  case).
# Image mdb182.pgm moved to Fatty-Glandular(G  case).
# Image mdb159.pgm moved to Fatty(F  case).
# Image mdb178.pgm moved to Fatty-Glandular(G  case).
# Image mdb165.pgm moved to Dense-Glandular(D  case).
# Image mdb171.pgm moved to Dense-Glandular(D  case).
# Image mdb181.pgm moved to Fatty-Glandular(G  case).
# Image mdb162.pgm moved to Dense-Glandular(D  case).
# Image mdb158.pgm moved to Fatty(F  case).
# Image mdb194.pgm moved to Dense-Glandular(D  case).
# Image mdb198.pgm moved to Dense-Glandular(D  case).
# Image mdb205.pgm moved to Fatty(F  case).
# Image mdb196.pgm moved to Fatty(F  case).
# Image mdb195.pgm moved to Fatty(F  case).
# Image mdb200.pgm moved to Dense-Glandular(D  case).
# Image mdb188.pgm moved to Fatty-Glandular(G  case).
# Image mdb186.pgm moved to Fatty-Glandular(G  case).
# Image mdb197.pgm moved to Dense-Glandular(D  case).
# Image mdb192.pgm moved to Fatty-Glandular(G  case).
# Image mdb193.pgm moved to Dense-Glandular(D  case).
# Image mdb187.pgm moved to Fatty-Glandular(G  case).
# Image mdb202.pgm moved to Dense-Glandular(D  case).
# Image mdb190.pgm moved to Fatty-Glandular(G  case).
# Image mdb199.pgm moved to Dense-Glandular(D  case).
# Image mdb184.pgm moved to Fatty(F  case).
# Image mdb201.pgm moved to Dense-Glandular(D  case).
# Image mdb206.pgm moved to Fatty(F  case).
# Image mdb191.pgm moved to Fatty-Glandular(G  case).
# Image mdb203.pgm moved to Fatty(F  case).
# Image mdb189.pgm moved to Fatty-Glandular(G  case).
# Image mdb185.pgm moved to Fatty-Glandular(G  case).
# Image mdb204.pgm moved to Fatty(F  case).
# Image mdb214.pgm moved to Fatty-Glandular(G  case).
# Image mdb213.pgm moved to Fatty-Glandular(G  case).
# Image mdb223.pgm moved to Dense-Glandular(D  case).
# Image mdb225.pgm moved to Dense-Glandular(D  case).
# Image mdb218.pgm moved to Fatty-Glandular(G  case).
# Image mdb220.pgm moved to Fatty-Glandular(G  case).
# Image mdb222.pgm moved to Dense-Glandular(D  case).
# Image mdb229.pgm moved to Fatty(F  case).
# Image mdb210.pgm moved to Fatty-Glandular(G  case).
# Image mdb227.pgm moved to Fatty-Glandular(G  case).
# Image mdb224.pgm moved to Dense-Glandular(D  case).
# Image mdb216.pgm moved to Dense-Glandular(D  case).
# Image mdb219.pgm moved to Fatty-Glandular(G  case).
# Image mdb226.pgm moved to Dense-Glandular(D  case).
# Image mdb209.pgm moved to Fatty-Glandular(G  case).
# Image mdb208.pgm moved to Dense-Glandular(D  case).
# Image mdb217.pgm moved to Fatty-Glandular(G  case).
# Image mdb211.pgm moved to Fatty-Glandular(G  case).
# Image mdb212.pgm moved to Fatty-Glandular(G  case).
# Image mdb230.pgm moved to Fatty(F  case).
# Image mdb207.pgm moved to Dense-Glandular(D  case).
# Image mdb221.pgm moved to Dense-Glandular(D  case).
# Image mdb215.pgm moved to Dense-Glandular(D  case).
# Image mdb228.pgm moved to Fatty-Glandular(G  case).
# Image mdb234.pgm moved to Fatty-Glandular(G  case).
# Image mdb242.pgm moved to Dense-Glandular(D  case).
# Image mdb251.pgm moved to Fatty(F  case).
# Image mdb238.pgm moved to Fatty(F  case).
# Image mdb247.pgm moved to Fatty(F  case).
# Image mdb235.pgm moved to Dense-Glandular(D  case).
# Image mdb231.pgm moved to Fatty(F  case).
# Image mdb245.pgm moved to Fatty(F  case).
# Image mdb236.pgm moved to Dense-Glandular(D  case).
# Image mdb233.pgm moved to Fatty-Glandular(G  case).
# Image mdb232.pgm moved to Fatty(F  case).
# Image mdb241.pgm moved to Dense-Glandular(D  case).
# Image mdb246.pgm moved to Fatty(F  case).
# Image mdb252.pgm moved to Fatty(F  case).
# Image mdb240.pgm moved to Dense-Glandular(D  case).
# Image mdb250.pgm moved to Dense-Glandular(D  case).
# Image mdb243.pgm moved to Dense-Glandular(D  case).
# Image mdb253.pgm moved to Dense-Glandular(D  case).
# Image mdb244.pgm moved to Dense-Glandular(D  case).
# Image mdb239.pgm moved to Dense-Glandular(D  case).
# Image mdb249.pgm moved to Dense-Glandular(D  case).
# Image mdb248.pgm moved to Fatty(F  case).
# Image mdb237.pgm moved to Fatty(F  case).
# Image mdb268.pgm moved to Fatty(F  case).
# Image mdb267.pgm moved to Fatty(F  case).
# Image mdb275.pgm moved to Fatty-Glandular(G  case).
# Image mdb261.pgm moved to Dense-Glandular(D  case).
# Image mdb262.pgm moved to Dense-Glandular(D  case).
# Image mdb272.pgm moved to Fatty(F  case).
# Image mdb260.pgm moved to Dense-Glandular(D  case).
# Image mdb263.pgm moved to Fatty-Glandular(G  case).
# Image mdb256.pgm moved to Fatty(F  case).
# Image mdb265.pgm moved to Fatty-Glandular(G  case).
# Image mdb274.pgm moved to Fatty(F  case).
# Image mdb258.pgm moved to Dense-Glandular(D  case).
# Image mdb255.pgm moved to Fatty(F  case).
# Image mdb270.pgm moved to Fatty-Glandular(G  case).
# Image mdb269.pgm moved to Fatty-Glandular(G  case).
# Image mdb271.pgm moved to Fatty(F  case).
# Image mdb254.pgm moved to Dense-Glandular(D  case).
# Image mdb259.pgm moved to Dense-Glandular(D  case).
# Image mdb266.pgm moved to Fatty-Glandular(G  case).
# Image mdb264.pgm moved to Fatty-Glandular(G  case).
# Image mdb257.pgm moved to Dense-Glandular(D  case).
# Image mdb273.pgm moved to Fatty(F  case).
# Image mdb289.pgm moved to Dense-Glandular(D  case).
# Image mdb294.pgm moved to Fatty(F  case).
# Image mdb284.pgm moved to Dense-Glandular(D  case).
# Image mdb290.pgm moved to Dense-Glandular(D  case).
# Image mdb297.pgm moved to Fatty(F  case).
# Image mdb276.pgm moved to Fatty-Glandular(G  case).
# Image mdb278.pgm moved to Fatty-Glandular(G  case).
# Image mdb288.pgm moved to Dense-Glandular(D  case).
# Image mdb281.pgm moved to Dense-Glandular(D  case).
# Image mdb282.pgm moved to Dense-Glandular(D  case).
# Image mdb287.pgm moved to Dense-Glandular(D  case).
# Image mdb291.pgm moved to Fatty-Glandular(G  case).
# Image mdb295.pgm moved to Dense-Glandular(D  case).
# Image mdb286.pgm moved to Dense-Glandular(D  case).
# Image mdb285.pgm moved to Dense-Glandular(D  case).
# Image mdb277.pgm moved to Fatty-Glandular(G  case).
# Image mdb296.pgm moved to Dense-Glandular(D  case).
# Image mdb283.pgm moved to Dense-Glandular(D  case).
# Image mdb280.pgm moved to Fatty-Glandular(G  case).
# Image mdb293.pgm moved to Fatty(F  case).
# Image mdb292.pgm moved to Fatty-Glandular(G  case).
# Image mdb298.pgm moved to Fatty(F  case).
# Image mdb299.pgm moved to Fatty(F  case).
# Image mdb279.pgm moved to Fatty-Glandular(G  case).
# Image mdb308.pgm moved to Fatty(F  case).
# Image mdb317.pgm moved to Dense-Glandular(D  case).
# Image mdb307.pgm moved to Fatty(F  case).
# Image mdb305.pgm moved to Fatty(F  case).
# Image mdb312.pgm moved to Fatty(F  case).
# Image mdb302.pgm moved to Fatty(F  case).
# Image mdb321.pgm moved to Dense-Glandular(D  case).
# Image mdb322.pgm moved to Dense-Glandular(D  case).
# Image mdb315.pgm moved to Dense-Glandular(D  case).
# Image mdb316.pgm moved to Dense-Glandular(D  case).
# Image mdb301.pgm moved to Fatty(F  case).
# Image mdb313.pgm moved to Fatty(F  case).
# Image mdb300.pgm moved to Fatty(F  case).
# Image mdb310.pgm moved to Fatty(F  case).
# Image mdb318.pgm moved to Dense-Glandular(D  case).
# Image mdb303.pgm moved to Fatty(F  case).
# Image mdb319.pgm moved to Dense-Glandular(D  case).
# Image mdb304.pgm moved to Fatty(F  case).
# Image mdb314.pgm moved to Fatty(F  case).
# Image mdb311.pgm moved to Fatty(F  case).
# Image mdb309.pgm moved to Fatty(F  case).
# Image mdb320.pgm moved to Dense-Glandular(D  case).
# Image mdb306.pgm moved to Fatty(F  case).
# Finished converting and sorting dataset.

# %%
print(os.listdir('/content/gdrive/MyDrive/mini-MIAS/images_processed'))
# Out:
# ['fatty', 'fatty_glandular', 'dense_glandular']

# %%
from torchvision import transforms, datasets, models

image_transforms = {
    # Train uses data augmentation
    'train':
    transforms.Compose([
        transforms.RandomRotation(degrees=10),
        transforms.RandomHorizontalFlip(),
        
        transforms.Resize((299,299)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])  # Imagenet standards
    ])}

# %%
def imshow_tensor(image, ax=None, title=None):

    if ax is None:
        fig, ax = plt.subplots()

    # Set the color channel as the third dimension
    image = image.numpy().transpose((1, 2, 0))

    # Reverse the preprocessing steps
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean

    # Clip the image pixel values
    image = np.clip(image, 0, 1)

    ax.imshow(image)
    plt.axis('off')

    return ax, image

# %%
from torch.utils.data import DataLoader, sampler, random_split

batch_size = 1

all_data = datasets.ImageFolder('/content/gdrive/MyDrive/mini-MIAS/images_processed',
                                transform=image_transforms['train'])
#train_data_len = int(len(all_data)*0.8)
#valid_data_len = int((len(all_data) - train_data_len)/2)
#test_data_len = int(len(all_data) - train_data_len - valid_data_len)
#train_data, val_data, test_data = random_split(all_data, [train_data_len, valid_data_len, test_data_len])
#train_data.dataset.transform = image_transforms['train']
#val_data.dataset.transform = image_transforms['val']
#test_data.dataset.transform = image_transforms['test']
#print(len(train_data), len(val_data), len(test_data))

data_loader = DataLoader(all_data, batch_size=batch_size, shuffle=True)
##val_loader = DataLoader(val_data, batch_size=batch_size, shuffle=True)
#test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
trainiter = iter(data_loader)
features_train, labels_train = next(trainiter)
print(features_train.shape, labels_train.shape)
# Out:
# torch.Size([1, 3, 299, 299]) torch.Size([1])

# %%
model = models.vgg16_bn(pretrained=True)

import torch
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=model.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# HBox(children=(FloatProgress(value=0.0, max=553507836.0), HTML(value='')))

# %%
model.features
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): ReLU(inplace=True)
#   (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (9): ReLU(inplace=True)
#   (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (12): ReLU(inplace=True)
#   (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (16): ReLU(inplace=True)
#   (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (19): ReLU(inplace=True)
#   (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (22): ReLU(inplace=True)
#   (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (26): ReLU(inplace=True)
#   (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (29): ReLU(inplace=True)
#   (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (32): ReLU(inplace=True)
#   (33): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (36): ReLU(inplace=True)
#   (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (39): ReLU(inplace=True)
#   (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (42): ReLU(inplace=True)
#   (43): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
# )

# %%
model.avgpool
# Out:
# AdaptiveAvgPool2d(output_size=(7, 7))
